# %% [markdown]
# # Extract data from all in test set

# %%
import pandas as pd
import numpy as np
import re
from collections import defaultdict
import os
import json
import pickle
import pdfplumber


from wealthnet_helpers import *

# %%
no_title_tables = {'career_history':['Company', 'Type', 'Position Held', 'YearStarted', 'YearEnded',
       'Remarks'],
       'philanthropy':['giving_profile'],
       'political_interests':['Political Profile'],
       'known_associates':['Name', 'Company', 'Relationships', 'Remarks'],
       'service_providers':['Name', 'Company', 'Position', 'Remarks'],
       'family_details':['Relation', 'Name', 'Age', 'Remarks']
       }

table2df_params = pd.DataFrame({'table_name':['Family Details', 'Biography','Career History', 
                                              'Wealth Analysis', 'Clubs & Boards', 'Known Associates', 'Service Providers', 'Philanthropy'],
'table_id':['family_details', 'biograhy','career_history', 
                                              'wealth_analysis', 'clubs_and_boards', 'known_associates', 'service_providers', 'philanthropy'],
'data_start':[3,1,2,2,2,2,2,1],
'column_names':[2,0,1,1,1,1,1,0]})

# %%
city_path = './data/london'

target_files = os.listdir(city_path)

files_dict = {}

for file_path in target_files:
    pdf = pdfplumber.open(city_path+ '/' + file_path )

    name = re.search(r'Wealth-X (.+?)(?:\sDossier(?:\s\(\d+\))?\.pdf)', file_path).group(1)
    print(name)
    tables_dict = extract_all_tables(pdf, table2df_params, no_title_tables)

    tables_dict['summary'] = extract_summary_data(pdf)

    tables_dict = clean_uhnw_dict_elements(tables_dict)

    tables_dict = combine_dataframes_with_suffix(tables_dict)

    files_dict[name] = tables_dict
# Out:
# Ajay Kalsi
# Abdulsalam Abdulrahman Nasser Al Agil
# Ahmed Zaki Yamani
# Abdullah Abdo Saeed Anam
# Albertino A. Abela
# Alan Eldad Howard
# Aidan Brooks
# Abdulsamad Rabiu
# Abdul Gabbar Hayel Saeed Anam
# Ahti Pentti Vilppula

# %%
def process_city_files(city_path, new_folder_path):
    target_files = os.listdir(city_path)
    city_name = os.path.basename(city_path)

    city_json_folder = os.path.join(new_folder_path, city_name)
    os.makedirs(city_json_folder, exist_ok=True)

    for file_path in target_files:
        pdf_file_path = os.path.join(city_path, file_path)
        json_file_name = os.path.splitext(file_path)[0] + '.json'
        json_file_path = os.path.join(city_json_folder, json_file_name)
        print(file_path)
        name = re.search(r'Wealth-X (.+?)(?:\sDossier(?:\s\(\d+\))?\.pdf)', file_path).group(1)
        #print(name)
        
        pdf = pdfplumber.open(pdf_file_path)

        tables_dict = extract_all_tables(pdf, table2df_params, no_title_tables)

        tables_dict['summary'] = extract_summary_data(pdf)

        tables_dict = clean_uhnw_dict_elements(tables_dict)

        tables_dict = combine_dataframes_with_suffix(tables_dict)

        with open(json_file_path, 'wb') as file:
            pickle.dump(tables_dict, file)
        
        pdf.close()

# %%
city_path = './data/cleaned_cities/London'
new_folder_path = './data/cities_json'
process_city_files(city_path, new_folder_path)
# Out:
# Wealth-X Mohamed Younes Mansour Loutfy Mansour Dossier.pdf
# Wealth-X Mark Richard Shuttleworth Dossier.pdf
# Wealth-X Isabel Jose dos Santos Dossier.pdf
# Wealth-X Sunil Sunderdas Vaswani Dossier.pdf
# Wealth-X Andrey Vagnerovich Andreev Dossier.pdf
# Wealth-X Anand Chand Burman Dossier.pdf
# Wealth-X Elliott Aintabi Dossier.pdf
# Wealth-X Ioannis A. Angelicoussis Dossier.pdf
# Wealth-X Sol Zakay Dossier.pdf
# Wealth-X Lev Avnerovich Leviev Dossier.pdf
# Wealth-X David Alliance Dossier.pdf
# Wealth-X Paul Brierley Smith Dossier.pdf
# Wealth-X Eyal Mordechai Ofer Dossier.pdf
# Wealth-X Patokh K. Chodiev Dossier.pdf
# Wealth-X Eugene Markovich Shvidler Dossier.pdf
# Wealth-X Harold Jonathan Esmond Vere Harmsworth Dossier.pdf
# Wealth-X Robert Warren Miller Dossier.pdf
# Wealth-X Philip William Hulme Dossier.pdf
# Wealth-X Simon Phillip Cowell Dossier.pdf
# Wealth-X Salim Ismail Kheireddine Dossier.pdf
# Wealth-X Dawood Pervez Dossier.pdf
# Wealth-X James Bruce Flatt Dossier.pdf
# Wealth-X Mikhail Maratovich Fridman Dossier.pdf
# Wealth-X Nichola Pease Dossier (1).pdf
# Wealth-X Mikhail Vyacheslavovich Krupeev Dossier.pdf
# Wealth-X Troels Holch Povlsen Dossier.pdf
# Wealth-X Graham Sharp Dossier.pdf
# Wealth-X Carl M. Hirschmann Dossier.pdf
# Wealth-X Thaksin Shinawatra Dossier.pdf
# Wealth-X Farhad Ardavan Moshiri Dossier.pdf
# Wealth-X Gert-Rudolf Flick Dossier.pdf
# Wealth-X Bassim Said Haidar Dossier.pdf
# Wealth-X Kirsty Elisabeth Bertarelli Dossier.pdf
# Wealth-X Ayman Asfari Dossier.pdf
# Wealth-X Pallonji Shapoorji Mistry Dossier.pdf
# Wealth-X Elena Nikolayevna Baturina Dossier.pdf
# Wealth-X Demetrio Carceller Arce Dossier.pdf
# Wealth-X Haralambos Kritonas Christodoulos Leventis Dossier.pdf
# Wealth-X Jonathan Michael Hunt Dossier.pdf
# Wealth-X Spencer Nicholas Roditi Dossier.pdf
# Wealth-X Jorn Anders Ola Rausing Dossier.pdf
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 city_path = './data/cleaned_cities/London'
#       2 new_folder_path = './data/cities_json'
# ----> 3 process_city_files(city_path, new_folder_path)
#
# Cell In[6], line 18, in process_city_files(city_path, new_folder_path)
#      14 #print(name)
#      16 pdf = pdfplumber.open(pdf_file_path)
# ---> 18 tables_dict = extract_all_tables(pdf, table2df_params, no_title_tables)
#      20 tables_dict['summary'] = extract_summary_data(pdf)
#      22 tables_dict = clean_uhnw_dict_elements(tables_dict)
#
# File ~/wealthnets/wealthnet_helpers.py:198, in extract_all_tables(pdf, table2df_params, no_title_tables, verbose)
#     196 result = set(value).issubset(table_temp[0])
#     197 if result:
# --> 198     out = correct_table_headers(table_temp)
#     200     # Add table count handling
#     201     table_counter[key] = table_counter.get(key, 0) + 1
#
# File ~/wealthnets/wealthnet_helpers.py:140, in correct_table_headers(table_temp)
#     137         table_temp2[0].insert(index, None)
#     139 # ensure we have the correct number of column names
# --> 140 assert len(table_temp2[0]) == len(df_temp.columns)
#     142 # assign the corrected headers to the dataframe
#     143 df_temp.columns = table_temp2[0]
#
# AssertionError:

# %%
city_path = './data/cleaned_cities/London'
target_files = os.listdir(city_path)
target_files
# Out:
# ['Wealth-X Mohamed Younes Mansour Loutfy Mansour Dossier.pdf',
#  'Wealth-X Mark Richard Shuttleworth Dossier.pdf',
#  'Wealth-X Isabel Jose dos Santos Dossier.pdf',
#  'Wealth-X Sunil Sunderdas Vaswani Dossier.pdf',
#  'Wealth-X Andrey Vagnerovich Andreev Dossier.pdf',
#  'Wealth-X Anand Chand Burman Dossier.pdf',
#  'Wealth-X Elliott Aintabi Dossier.pdf',
#  'Wealth-X Ioannis A. Angelicoussis Dossier.pdf',
#  'Wealth-X Sol Zakay Dossier.pdf',
#  'Wealth-X Lev Avnerovich Leviev Dossier.pdf',
#  'Wealth-X David Alliance Dossier.pdf',
#  'Wealth-X Paul Brierley Smith Dossier.pdf',
#  'Wealth-X Eyal Mordechai Ofer Dossier.pdf',
#  'Wealth-X Patokh K. Chodiev Dossier.pdf',
#  'Wealth-X Eugene Markovich Shvidler Dossier.pdf',
#  'Wealth-X Harold Jonathan Esmond Vere Harmsworth Dossier.pdf',
#  'Wealth-X Robert Warren Miller Dossier.pdf',
#  'Wealth-X Philip William Hulme Dossier.pdf',
#  'Wealth-X Simon Phillip Cowell Dossier.pdf',
#  'Wealth-X Salim Ismail Kheireddine Dossier.pdf',
#  'Wealth-X Dawood Pervez Dossier.pdf',
#  'Wealth-X James Bruce Flatt Dossier.pdf',
#  'Wealth-X Mikhail Maratovich Fridman Dossier.pdf',
#  'Wealth-X Nichola Pease Dossier (1).pdf',
#  'Wealth-X Mikhail Vyacheslavovich Krupeev Dossier.pdf',
#  'Wealth-X Troels Holch Povlsen Dossier.pdf',
#  'Wealth-X Graham Sharp Dossier.pdf',
#  'Wealth-X Carl M. Hirschmann Dossier.pdf',
#  'Wealth-X Thaksin Shinawatra Dossier.pdf',
#  'Wealth-X Farhad Ardavan Moshiri Dossier.pdf',
#  'Wealth-X Gert-Rudolf Flick Dossier.pdf',
#  'Wealth-X Bassim Said Haidar Dossier.pdf',
#  'Wealth-X Kirsty Elisabeth Bertarelli Dossier.pdf',
#  'Wealth-X Ayman Asfari Dossier.pdf',
#  'Wealth-X Pallonji Shapoorji Mistry Dossier.pdf',
#  'Wealth-X Elena Nikolayevna Baturina Dossier.pdf',
#  'Wealth-X Demetrio Carceller Arce Dossier.pdf',
#  'Wealth-X Haralambos Kritonas Christodoulos Leventis Dossier.pdf',
#  'Wealth-X Jonathan Michael Hunt Dossier.pdf',
#  'Wealth-X Spencer Nicholas Roditi Dossier.pdf',
#  'Wealth-X Jorn Anders Ola Rausing Dossier.pdf',
#  'Wealth-X Eric Christian Jacques de Turckheim Dossier (1).pdf',
#  'Wealth-X Richard Allan Caring Dossier.pdf',
#  'Wealth-X Benjamin Robert Pollner Dossier (1).pdf',
#  'Wealth-X Stephen Gerard Pycroft Dossier.pdf',
#  'Wealth-X Jianlin Wang Dossier.pdf',
#  'Wealth-X Kartar T. Lalvani Dossier.pdf',
#  'Wealth-X David Brian Thompson Dossier.pdf',
#  'Wealth-X Peter Thomas Smedvig Dossier (1).pdf',
#  'Wealth-X Alexander Antonovich Machkevitch Dossier.pdf',
#  'Wealth-X Christina Ong Dossier (1).pdf',
#  'Wealth-X Riccardo Silva Dossier.pdf',
#  'Wealth-X Pramod Kumar Agarwal Dossier.pdf',
#  'Wealth-X Charles William Dunstone Dossier.pdf',
#  'Wealth-X Wafic Rida Said Dossier.pdf',
#  'Wealth-X Ajay Kalsi Dossier.pdf',
#  'Wealth-X Slawomir Smolokowski Dossier.pdf',
#  'Wealth-X Thomas Eric Sandell Dossier.pdf',
#  'Wealth-X Viatcheslav Vladimirovich Kantor Dossier.pdf',
#  'Wealth-X Mohammed Fathi Ibrahim Dossier.pdf',
#  'Wealth-X Alexander Leonidovich Mamut Dossier.pdf',
#  'Wealth-X Keith Rupert Murdoch Dossier.pdf',
#  'Wealth-X Youssef Younes Mansour Loutfy Mansour Dossier.pdf',
#  'Wealth-X Dermot Fachtna Desmond Dossier.pdf',
#  'Wealth-X Igor Alekseevich Altushkin Dossier.pdf',
#  'Wealth-X Aristotelis Mistakidis Dossier.pdf',
#  'Wealth-X Robyn Rihanna Fenty Dossier (1).pdf',
#  'Wealth-X Anne Beaufour Dossier.pdf',
#  'Wealth-X Andrey Nikolaevich Goncharenko Dossier.pdf',
#  'Wealth-X Vladimir Sergeyevich Kim Dossier.pdf',
#  'Wealth-X Dheeraj Gopichand Hinduja Dossier.pdf',
#  'Wealth-X Christoph Henkel Dossier.pdf',
#  'Wealth-X Henry Ross Perot Jr. Dossier.pdf',
#  'Wealth-X Michael Rubens Bloomberg Dossier.pdf',
#  'Wealth-X Marcus Simon Cooper Dossier (1).pdf',
#  'Wealth-X Hendrik Jacobus du Toit Dossier.pdf',
#  'Wealth-X Timur Askarovich Kulibayev Dossier.pdf',
#  'Wealth-X Waleed bin Ibrahim bin Abdulaziz Al Ibrahim Dossier.pdf',
#  'Wealth-X Lloyd Marshall Dorfman Dossier.pdf',
#  'Wealth-X Raymond Gabriel O’Rourke Dossier.pdf',
#  'Wealth-X Oleg Vladimirovich Deripaska Dossier.pdf',
#  'Wealth-X John Lincoln Duffield Dossier.pdf',
#  'Wealth-X Richard Buckland Farleigh Dossier (1).pdf',
#  'Wealth-X Anil Kumar Dossier (1).pdf',
#  'Wealth-X Srichand Parmanand Hinduja Dossier.pdf',
#  'Wealth-X Chalerm Yoovidhya Dossier.pdf',
#  'Wealth-X Evelyn Robert Adrian de Rothschild Dossier.pdf',
#  'Wealth-X Hans Kristian Rausing Dossier.pdf',
#  'Wealth-X Marianne Odfjell Dossier (1).pdf',
#  'Wealth-X Helene Odfjell Dossier.pdf',
#  'Wealth-X Richard John Livingstone Dossier.pdf',
#  'Wealth-X Abdulsalam Abdulrahman Nasser Al Agil Dossier.pdf',
#  'Wealth-X Teddy Sagi Dossier.pdf',
#  'Wealth-X Hamad bin Jassim bin Jabr bin Muhammad Al Thani Dossier.pdf',
#  'Wealth-X Lalit Kumar Modi Dossier (1).pdf',
#  'Wealth-X Gautam Thapar Dossier.pdf',
#  'Wealth-X Tatiana Casiraghi Dossier.pdf',
#  'Wealth-X Maurice S. Kanbar Dossier.pdf',
#  'Wealth-X Felix Grovit Dossier.pdf',
#  'Wealth-X Cristina Mayville Stenbeck Dossier (1).pdf',
#  'Wealth-X James Caan Dossier.pdf',
#  'Wealth-X Richard Clive Desmond Dossier.pdf',
#  'Wealth-X Boris Iosifovich Mints Dossier.pdf',
#  'Wealth-X Ahmed Zaki Yamani Dossier (1).pdf',
#  'Wealth-X Kolawole Akanni Aluko Dossier.pdf',
#  'Wealth-X Jaime Gilinski Bacal Dossier.pdf',
#  'Wealth-X George Garfield Weston Dossier.pdf',
#  'Wealth-X Xiu Li Dai Dossier.pdf',
#  'Wealth-X David John Lewis Dossier (1).pdf',
#  'Wealth-X Viktor Aleksandrovich Pichugov Dossier.pdf',
#  'Wealth-X Cyrus Pallonji Mistry Dossier.pdf',
#  'Wealth-X Sergio Mantegazza Dossier.pdf',
#  'Wealth-X Taavet Hinrikus Dossier.pdf',
#  'Wealth-X Niklas Achim Mathias Kamprad Dossier.pdf',
#  'Wealth-X Steven Anthony Blumgart Dossier.pdf',
#  'Wealth-X Martin Brian Hughes Dossier (1).pdf',
#  'Wealth-X John Peter Boden Dossier.pdf',
#  'Wealth-X Cameron Anthony Mackintosh Dossier.pdf',
#  'Wealth-X Christopher Charles Rokos Dossier.pdf',
#  'Wealth-X Yusuf Khwaja Hamied Dossier.pdf',
#  'Wealth-X Nasser David Khalili Dossier.pdf',
#  'Wealth-X Zameer Mohammed Choudrey Dossier.pdf',
#  'Wealth-X Bhai Analjit Singh Dossier.pdf',
#  'Wealth-X Robert Stephen Rubin Dossier.pdf',
#  'Wealth-X Shiraz Jafferali Lalji Dossier.pdf',
#  'Wealth-X Philip Stavros Niarchos Dossier.pdf',
#  'Wealth-X Arne Alexander Wilhelmsen Dossier.pdf',
#  'Wealth-X Kristo Kaarmann Dossier.pdf',
#  'Wealth-X Maritsa Lazari Dossier.pdf',
#  'Wealth-X Robert Ian Kauffman Dossier.pdf',
#  'Wealth-X John Richard Horseman Dossier.pdf',
#  'Wealth-X Violetta Caprotti Dossier.pdf',
#  'Wealth-X Timur Orazbekovich Kuanyshev Dossier.pdf',
#  'Wealth-X Jose Manuel Ferreira Neves Dossier.pdf',
#  'Wealth-X Alexander Vladimirovich Girda Dossier.pdf',
#  'Wealth-X Peter Andrew Cruddas Dossier.pdf',
#  'Wealth-X Igor Leonidovich Linshits Dossier.pdf',
#  'Wealth-X Francois-Henri Pinault Dossier.pdf',
#  'Wealth-X Badr Hamid Jafar Dossier.pdf',
#  'Wealth-X Arthur Ikpechukwu Eze Dossier.pdf',
#  'Wealth-X Nadhmi Shakir Auchi Dossier.pdf',
#  'Wealth-X George Horesh Dossier.pdf',
#  'Wealth-X Anthony Paul Bamford Dossier.pdf',
#  'Wealth-X German Borisovich Khan Dossier.pdf',
#  'Wealth-X Hajia Bola Muinat Shagaya Dossier.pdf',
#  'Wealth-X Philip Stephan Arnold Mallinckrodt Dossier.pdf',
#  'Wealth-X Alejandro Santo Domingo Davila Dossier.pdf',
#  'Wealth-X Tatparanandam Ananda Krishnan Dossier.pdf',
#  'Wealth-X Anna Lisbet Kristina Rausing Dossier.pdf',
#  'Wealth-X Charlene de Carvalho-Heineken Dossier.pdf',
#  'Wealth-X Marcin Pioro Dossier.pdf',
#  'Wealth-X Selina Stihl Dossier (1).pdf',
#  'Wealth-X Alisher Burkhanovich Usmanov Dossier.pdf',
#  'Wealth-X David Winton Harding Dossier.pdf',
#  'Wealth-X Ernesto Silvio Maurizio Bertarelli Dossier.pdf',
#  'Wealth-X Andreas Serenus Hoffmann Dossier.pdf',
#  'Wealth-X Sebastian Tomasz Kulczyk Dossier.pdf',
#  '+Wealth X search details.docx',
#  'Wealth-X Doron Ofer Dossier.pdf',
#  'Wealth-X David Babai Dossier.pdf',
#  'Wealth-X Peter Michael Beckwith Dossier (1).pdf',
#  'Wealth-X Silvio Scaglia Dossier.pdf',
#  'Wealth-X Abdullah Abdo Saeed Anam Dossier.pdf',
#  'Wealth-X Kristian Siem Dossier.pdf',
#  'Wealth-X Kenneth Cordele Griffin Dossier.pdf',
#  'Wealth-X Handojo Santosa Dossier.pdf',
#  'Wealth-X Michael Alan Spencer Dossier.pdf',
#  'Wealth-X Ashok Parmanand Hinduja Dossier.pdf',
#  'Wealth-X David Robert Joseph Beckham Dossier.pdf',
#  'Wealth-X Simon Robert Fuller Dossier.pdf',
#  'Wealth-X Michael Edward Platt Dossier.pdf',
#  'Wealth-X Yasseen Ibrahim Loutfy Mansour Dossier.pdf',
#  'Wealth-X Bernard Lewis Dossier.pdf',
#  'Wealth-X Albertino A. Abela Dossier (1).pdf',
#  'Wealth-X Philip Eric Hult Dossier.pdf',
#  'Wealth-X Stanley Stephen Tollman Dossier (1).pdf',
#  'Wealth-X Bruce Weir Ritchie Dossier.pdf',
#  'Wealth-X Lawrence Sheldon Strulovitch Dossier.pdf',
#  'Wealth-X Yevgeny Aleksandrovich Chichvarkin Dossier.pdf',
#  'Wealth-X Lakshmi Niwas Mittal Dossier.pdf',
#  'Wealth-X Alijan Rakhmanovich Ibragimov Dossier.pdf',
#  'Wealth-X Alexander Yevgenievich Lebedev Dossier.pdf',
#  'Wealth-X Robert Halley Dossier.pdf',
#  'Wealth-X Fred Done Dossier.pdf',
#  'Wealth-X Dickson Poon Dossier.pdf',
#  'Wealth-X Jean Pigozzi Dossier.pdf',
#  'Wealth-X Phillip Frost Dossier.pdf',
#  'Wealth-X Alexander Mark Knaster Dossier.pdf',
#  'Wealth-X Michael Anthony Ashcroft Dossier.pdf',
#  'Wealth-X Watche Agiche Manoukian Dossier.pdf',
#  "Wealth-X Hassanal Bolkiah Mu'izzaddin Waddaulah ibni Omar 'Ali Saifuddien Sa'adul Khairi Waddien Dossier.pdf",
#  'Wealth-X Michael Demetrius Chandris Dossier.pdf',
#  'Wealth-X Charles Gerald John Cadogan Dossier.pdf',
#  'Wealth-X Mohammad Zahoor Dossier.pdf',
#  'Wealth-X Laurence Graff Dossier.pdf',
#  'Wealth-X Christian Candy Dossier.pdf',
#  'Wealth-X Leng Chye Quek Dossier.pdf',
#  'Wealth-X John Alan Howard Frieda Dossier.pdf',
#  'Wealth-X Edward James Wray Dossier.pdf',
#  'Wealth-X Bruce Timothy Craig Dossier.pdf',
#  'Wealth-X Jean Claude Raymond Gandur Dossier.pdf',
#  'Wealth-X Stefan Sten Olsson Dossier.pdf',
#  'Wealth-X Eddie Zakay Dossier.pdf',
#  'Wealth-X Marlon Abela Dossier.pdf',
#  'Wealth-X Jordi Carulla Font Dossier.pdf',
#  'Wealth-X Chaim Zabludowicz Dossier.pdf',
#  'Wealth-X Ian Malcolm Livingstone Dossier.pdf',
#  'Wealth-X Alan Eldad Howard Dossier.pdf',
#  'Wealth-X Madonna Louise Veronica Ciccone Dossier.pdf',
#  'Wealth-X Mohammed Saud Salim Abdullah Bahwan Dossier.pdf',
#  'Wealth-X Bjorgolfur Thor Bjorgolfsson Dossier.pdf',
#  'Wealth-X William Felix Browder Dossier.pdf',
#  'Wealth-X Carl-Henric Svanberg Dossier.pdf',
#  'Wealth-X Miroslav Miskovic Dossier.pdf',
#  'Wealth-X Arthur Landon Dossier (1).pdf',
#  'Wealth-X Sigrid Maria Elisabet Rausing Dossier.pdf',
#  'Wealth-X Julian Edward Metcalfe Dossier.pdf',
#  'Wealth-X Gregory John Coffey Dossier.pdf',
#  'Wealth-X Dirhem Abdo Saeed Anam Dossier.pdf',
#  'Wealth-X Valentino Clemente Ludovico Garavani Dossier.pdf',
#  'Wealth-X Zeljko Ranogajec Dossier.pdf',
#  'Wealth-X Eduard Vladimirovich Shifrin Dossier.pdf',
#  'Wealth-X Riccardo Zacconi Dossier.pdf',
#  'Wealth-X Vivien Duffield Dossier.pdf',
#  'Wealth-X David MacKellar Richwhite Dossier.pdf',
#  'Wealth-X Eric Niels Heerema Dossier.pdf',
#  'Wealth-X Petr Kellner Dossier.pdf',
#  'Wealth-X Arkady Anatolyevich Novikov Dossier.pdf',
#  'Wealth-X Oleg Novachuk Dossier.pdf',
#  'Wealth-X Alshair Fiyaz Dossier.pdf',
#  'Wealth-X Rizwan Pervez Dossier.pdf',
#  'Wealth-X Michael David William Gooley Dossier (1).pdf',
#  'Wealth-X Paolo Amir Parviz Dossier.pdf',
#  'Wealth-X Leonard Valentinovich Blavatnik Dossier.pdf',
#  'Wealth-X Dennis Barry Gillings Dossier.pdf',
#  'Wealth-X Sinclair Beecham Dossier.pdf',
#  'Wealth-X Peter George Livanos Dossier.pdf',
#  'Wealth-X Maurice Salem Dossier (1).pdf',
#  'Wealth-X James Hull Dossier.pdf',
#  'Wealth-X Bernard Charles Ecclestone Dossier.pdf',
#  'Wealth-X Anne Louisa Philip Mann Dossier (1).pdf',
#  'Wealth-X Shashikant Nand Kishore Ruia Dossier.pdf',
#  'Wealth-X Andrew Eric Law Dossier.pdf',
#  'Wealth-X Lapo Eduard Elkann Dossier (1).pdf',
#  'Wealth-X Alexander Mikhailovich Bronstein Dossier.pdf',
#  'Wealth-X Hans Jonas Ingvar Kamprad Dossier.pdf',
#  'Wealth-X Folorunsho Alakija Dossier.pdf',
#  'Wealth-X Nathaniel Charles Jacob Rothschild Dossier.pdf',
#  'Wealth-X Lily Safra Dossier.pdf',
#  'Wealth-X Michael Thomas Danson Dossier.pdf',
#  'Wealth-X Surinder Arora Dossier.pdf',
#  'Wealth-X Richard Charles Nicholas Branson Dossier.pdf',
#  'Wealth-X Polys Haji-Ioannou Dossier.pdf',
#  'Wealth-X Asif Haroon Aziz Dossier.pdf',
#  'Wealth-X Hamish Macgregor Ogston Dossier.pdf',
#  'Wealth-X David Reuben Dossier.pdf',
#  'Wealth-X Swraj Paul Dossier.pdf',
#  'Wealth-X Vladimir Nikolaevich Makhlai Dossier.pdf',
#  'Wealth-X Yiannakis Theophani Christodoulou Dossier.pdf',
#  'Wealth-X Graham John Tuckwell Dossier.pdf',
#  'Wealth-X Cyrus K. Vandrevala Dossier.pdf',
#  'Wealth-X Bruce Gordon Dossier.pdf',
#  'Wealth-X Paul Coulson Dossier.pdf',
#  'Wealth-X Mark Joseph Cyril Bamford Dossier.pdf',
#  'Wealth-X Antonio Luiz da Cunha Seabra Dossier.pdf',
#  'Wealth-X Jose Manuel Rodrigues Berardo Dossier.pdf',
#  'Wealth-X Fahad Mohammed Saleh Al Athel Dossier.pdf',
#  'Wealth-X Toufic Aboukhater Dossier.pdf',
#  'Wealth-X James Dyson Dossier.pdf',
#  'Wealth-X Andrea Pignataro Dossier.pdf',
#  'Wealth-X Robert Paul Finch Dossier.pdf',
#  'Wealth-X Vernon W. Hill II Dossier (1).pdf',
#  'Wealth-X Bhupendra Kumar Modi Dossier.pdf',
#  'Wealth-X Jean-Victor Guido Pastor Dossier.pdf',
#  'Wealth-X Marcus Paul Bruce Evans Dossier.pdf',
#  'Wealth-X Lance Darrell Gordon Uggla Dossier.pdf',
#  'Wealth-X Mark Andrew Pears Dossier.pdf',
#  'Wealth-X Solomon Kerzner Dossier.pdf',
#  'Wealth-X Tak Yee Lee Dossier.pdf',
#  'Wealth-X Kirill Valerievich Pisarev Dossier.pdf',
#  'Wealth-X Roger Michael de Haan Dossier.pdf',
#  'Wealth-X Peter Michael Simon Dossier.pdf',
#  'Wealth-X Mohammed Halim Fares Al Rahbani Dossier (1).pdf',
#  'Wealth-X Katharina Johanna Braun Dossier.pdf',
#  'Wealth-X Patrick Anthony McKenna Dossier.pdf',
#  'Wealth-X Idan Ofer Dossier.pdf',
#  'Wealth-X Eliezer Kobo Dossier.pdf',
#  'Wealth-X Frederic Marguerre Dossier.pdf',
#  'Wealth-X Robert Tchenguiz Dossier.pdf',
#  'Wealth-X Anne-Marie Graff Dossier.pdf',
#  'Wealth-X Mohamed bin Issa Al Jaber Dossier.pdf',
#  'Wealth-X Brian Anthony Charles Kingham Dossier.pdf',
#  'Wealth-X Viktor Mikhailovich Pinchuk Dossier.pdf',
#  'Wealth-X Duncan Walker Bannatyne Dossier.pdf',
#  'Wealth-X Sri Prakash Lohia Dossier.pdf',
#  'Wealth-X Raghuvinder Kataria Dossier.pdf',
#  'Wealth-X Henri Beaufour Dossier.pdf',
#  'Wealth-X Roman Arkadievich Abramovich Dossier.pdf',
#  'Wealth-X Victor Phillip Michael Dahdaleh Dossier.pdf',
#  'Wealth-X John Demetrius Chandris Dossier.pdf',
#  'Wealth-X Mohammed Saleh Affara Dossier.pdf',
#  'Wealth-X Ronald Wayne Burkle Dossier.pdf',
#  'Wealth-X Mark Langhorn Coombs Dossier.pdf',
#  'Wealth-X Siew Choon Lim Dossier.pdf',
#  'Wealth-X Andrew Black Dossier.pdf',
#  'Wealth-X James Arthur Ratcliffe Dossier.pdf',
#  'Wealth-X John Patrick Grayken Dossier.pdf',
#  'Wealth-X Francois Hubert Marie Perrodo Dossier.pdf',
#  'Wealth-X Modupe Alakija Dossier.pdf',
#  'Wealth-X Vladislav Yurievich Doronin Dossier.pdf',
#  'Wealth-X Prakashchand Parmanand Hinduja Dossier.pdf',
#  'Wealth-X Eleonora Berlusconi Dossier (1).pdf',
#  'Wealth-X Igor Tsukanov Dossier (2).pdf',
#  'Wealth-X Jack Petchey Dossier.pdf',
#  'Wealth-X Gopichand Parmanand Hinduja Dossier.pdf',
#  'Wealth-X Jeremy John Hosking Dossier.pdf',
#  'Wealth-X Vasile Frank Timis Dossier.pdf',
#  'Wealth-X Elizabeth Alexandra Mary Windsor Dossier.pdf',
#  'Wealth-X Anthony Selwyn Tabatznik Dossier (1).pdf',
#  'Wealth-X Anil K. Agarwal Dossier.pdf',
#  'Wealth-X Joanne Kathleen Rowling Dossier.pdf',
#  'Wealth-X James Paul McCartney Dossier.pdf',
#  'Wealth-X James Munir Hay Dossier.pdf',
#  'Wealth-X Aidan Brooks Dossier (1).pdf',
#  'Wealth-X Ian Gerald Patrick Wace Dossier.pdf',
#  'Wealth-X Turki Bin Nasser Bin Abdul Aziz Al Saud Dossier.pdf',
#  'Wealth-X Igor Tsukanov Dossier (1).pdf',
#  'Wealth-X David Manuel Martinez Guzman Dossier.pdf',
#  'Wealth-X Alexei Leonidovich Polezhaev Dossier.pdf',
#  'Wealth-X Carl Johan Martin Eliasch Dossier.pdf',
#  'Wealth-X Chun Kuen Woo Dossier.pdf',
#  'Wealth-X John Lionel Beckwith Dossier.pdf',
#  'Wealth-X Abdulsamad Rabiu Dossier.pdf',
#  'Wealth-X Omer Mehmet Koc Dossier.pdf',
#  'Wealth-X Ravi Kumar Mehrotra Dossier (1).pdf',
#  'Wealth-X Gennady Borisovich Bogolyubov Dossier.pdf',
#  'Wealth-X Gerard William Ford Dossier.pdf',
#  'Wealth-X Mohammed Mahdi Al Tajir Dossier.pdf',
#  'Wealth-X Robert C. Dart Dossier.pdf',
#  'Wealth-X Andrey Mikhaylovich Verevskiy Dossier.pdf',
#  'Wealth-X Gautam Hari Singhania Dossier.pdf',
#  'Wealth-X John David Caudwell Dossier.pdf',
#  'Wealth-X Denise Joy Rich Dossier.pdf',
#  'Wealth-X Kwok Po Li Dossier (1).pdf',
#  'Wealth-X Louis Moore Bacon Dossier.pdf',
#  'Wealth-X Abdul Gabbar Hayel Saeed Anam Dossier.pdf',
#  'Wealth-X Gary Mischa Fegel Dossier.pdf',
#  'Wealth-X Ka Yee Perrodo Dossier.pdf',
#  'Wealth-X Wen Yang Wong Dossier (1).pdf',
#  'Wealth-X Konstantin Ivanovich Grigorishin Dossier.pdf',
#  'Wealth-X Anastasios-Pavlos Christodoulos Leventis Dossier.pdf',
#  'Wealth-X Mark M. Klabin Dossier (1).pdf',
#  'Wealth-X Viktor Vladimirovich Kharitonin Dossier (1).pdf',
#  'Wealth-X Konstantin Grigoryevich Kagalovsky Dossier.pdf',
#  'Wealth-X Magdi Abdul Latif Jameel Dossier.pdf',
#  'Wealth-X Olufemi Otedola Dossier (1).pdf',
#  'Wealth-X Steven Andrew Heinz Dossier.pdf',
#  'Wealth-X Kurt Alexander Engelhorn Dossier (1).pdf',
#  'Wealth-X Charlotte Anne Townshend Dossier (1).pdf',
#  'Wealth-X Ahti Pentti Vilppula Dossier.pdf',
#  'Wealth-X Askar Mutanovich Alshinbayev Dossier.pdf',
#  'Wealth-X Mohamed Abdel Moneim Al Fayed Dossier.pdf',
#  'Wealth-X Daniel Maurice Wagner Dossier.pdf',
#  'Wealth-X George J. Prokopiou Dossier.pdf',
#  'Wealth-X Mohammed Anwar Pervez Dossier.pdf',
#  'Wealth-X Michael James Wallace Ashley Dossier.pdf',
#  'Wealth-X Shahrukh Khan Dossier.pdf',
#  'Wealth-X William Shenkman Dossier (1).pdf',
#  'Wealth-X Gordon Stewart Dossier.pdf',
#  'Wealth-X Mohammed Hussein Ali Al Amoudi Dossier.pdf',
#  'Wealth-X Peter John de Savary Dossier.pdf',
#  'Wealth-X Vivian Saul Imerman Dossier.pdf',
#  'Wealth-X Graham Henry Edwards Dossier.pdf',
#  'Wealth-X Douglas Alan Barrowman Dossier (1).pdf',
#  'Wealth-X Hamad bin Khalifa bin Hamad bin Abdullah bin Jassim Al Thani Dossier.pdf',
#  'Wealth-X Fadwa Yacoub Al Homaizi Dossier (1).pdf',
#  'Wealth-X Randolph David Lerner Dossier.pdf',
#  'Wealth-X Arpad A. Busson Dossier.pdf',
#  'Wealth-X Oleksandr Vladulenovuch Yaroslavsky Dossier.pdf',
#  'Wealth-X Michael Hintze Dossier.pdf',
#  'Wealth-X Alexander Grigoryevich Abramov Dossier.pdf',
#  'Wealth-X Kamel Alzarka Dossier.pdf',
#  'Wealth-X Niklas Marten Zennstrom Dossier.pdf',
#  'Wealth-X Alexander Frank Beard Dossier.pdf',
#  'Wealth-X Nathan Kirsh Dossier.pdf',
#  'Wealth-X Kostyantin Valentynovych Zhevaho Dossier.pdf',
#  'Wealth-X John Fredriksen Dossier.pdf',
#  'Wealth-X Slavica Ecclestone Dossier.pdf',
#  'Wealth-X Ramkrishan Prakash Hinduja Dossier.pdf',
#  'Wealth-X Alexei Viktorovich Kuzmichev Dossier.pdf',
#  'Wealth-X Fouad Mustafa Makhzoumi Dossier.pdf',
#  'Wealth-X Robin Crispin William Odey Dossier.pdf',
#  'Wealth-X Ravikant Nand Kishore Ruia Dossier.pdf',
#  'Wealth-X Philip Nigel Ross Green Dossier.pdf',
#  'Wealth-X Rinat Leonidovych Akhmetov Dossier.pdf',
#  'Wealth-X Eric Guerlain Dossier (1).pdf',
#  'Wealth-X Leopold Noe Dossier.pdf',
#  'Wealth-X Irvine Alan Stewart Laidlaw Dossier.pdf',
#  'Wealth-X Henning Conle Dossier.pdf',
#  'Wealth-X Peter James Ogden Dossier (1).pdf',
#  'Wealth-X Yakir Yehuda Gabay Dossier.pdf']

# %%
city_path = './data/cleaned_cities/London'
file_path = 'Wealth-X Abdulsamad Rabiu Dossier.pdf'

pdf = pdfplumber.open(city_path+ '/' + file_path )

name = re.search(r'Wealth-X (.+?)(?:\sDossier(?:\s\(\d+\))?\.pdf)', file_path).group(1)
print(name)
tables_dict = extract_all_tables(pdf, table2df_params, no_title_tables, verbose=True)

tables_dict['summary'] = extract_summary_data(pdf)

tables_dict = clean_uhnw_dict_elements(tables_dict)

tables_dict = combine_dataframes_with_suffix(tables_dict, verbose=True)
# Out:
# Abdulsamad Rabiu
# page number 1 number of tables: 1
# Biography
# biograhy_2
# page number 2 number of tables: 3
# Career History
# career_history_2
# Wealth Analysis
# wealth_analysis_2
# List of Assets
# page number 3 number of tables: 4
# Interesting Facts
# Interests, Passions, Hobbies
# Philanthropy
# philanthropy_2
# Known Associates
# known_associates_2
# page number 4 number of tables: 1
# Name
# known_associates_3
# page number 5 number of tables: 4
# Name
# known_associates_4
# Service Providers
# service_providers_2
# Family Details
# family_details_2
# Contact Information
# defaultdict(<class 'list'>, {'biograhy': ['biograhy_2'], 'career_history': ['career_history_2'], 'wealth_analysis': ['wealth_analysis_2'], 'philanthropy': ['philanthropy_2'], 'known_associates': ['known_associates_2', 'known_associates_3', 'known_associates_4'], 'service_providers': ['service_providers_2'], 'family_details': ['family_details_2'], 'summary': ['summary']})
# biograhy
# career_history
# wealth_analysis
# philanthropy
# known_associates
# service_providers
# family_details
# summary

# %%
verbose = False
totalpages = len(pdf.pages)

tables_dict = {}
out = None
table_id = None
table_counter = {}  # A dictionary to count instances of each table

for page_number in range(1, totalpages):

    page = pdf.pages[page_number]

    table_settings={
        "vertical_strategy": "lines",
        "horizontal_strategy": "lines",
        "explicit_vertical_lines": page.curves, # used for extract table from page[0]
        "explicit_horizontal_lines": page.curves # used for extract table from page[0]
        }

    table = page.extract_tables(table_settings)
    #removes the \n newline symbold from the text
    table = recursively_apply(table, replace_chars)
    table = post_process_tables(table, no_title_tables)  # Call the post-processing function with no_title_tables
    
    if verbose:
        print("page number "+str(page_number)+" number of tables: " +str(len(table)))

    for n in range(0, len(table)):
        table_temp =table[n]
        if verbose:
            print(table_temp[0][0])
        
        if table_temp and len(table_temp[0]) > 0:
            sub_table = table2df_params.loc[[x == table_temp[0][0] for x in table2df_params['table_name']],:].reset_index(drop=True)
        
            if (sub_table.shape[0]==1):
                if sub_table['column_names'][0] < len(table_temp):
                    # Add table count handling
                    table_id_base = sub_table['table_id'].to_string(index = False)
                    if table_id_base not in table_counter:
                        table_counter[table_id_base] = 1  # Initialize the counter to 1
                    table_counter[table_id_base] = table_counter.get(table_id_base, 0) + 1
                    table_id = f"{table_id_base}_{table_counter[table_id_base]}"
                    column_names = rename_none_in_list(table_temp[sub_table['column_names'][0]])
                    out = pd.DataFrame(table_temp[sub_table['data_start'][0]:], columns = column_names)
            else:
                for key, value in no_title_tables.items():
                    result = set(value).issubset(table_temp[0])
                    if result:
                        print(table_temp)
                        out = correct_table_headers(table_temp)

                        # Add table count handling
                        table_counter[key] = table_counter.get(key, 0) + 1
                        table_id = f"{key}_{table_counter[key]}"

        if out is not None:
            if verbose:
                print(table_id)
                
            tables_dict[table_id] = out
            out = None
            table_id = None
# Out:
# [['Name', 'Company', 'Relationships', 'Remarks'], ['Kenneth Chimaobi MADUKWE', 'BUA Group', 'Business', 'COO of BUA Group.'], ['Arnold Alois SCHWARZENEGGER Confirmed UHNW', '', 'Business', 'Former U.S. California Governor presented the awards on the 16th ThisDay Awards in Lagos, of which Rabiu is a recipient.'], ['Confirmed UHNW', None, None, None], ['Oladimeji Sabur BANKOLE', '', 'Business', "Nigerian politician and Speaker of the House of Representatives of Nigeria attended Nigeria President Jonathan's Campaign Fund Raising Dinner in October, 2010 with Rabiu."], ['Ben NWABUEZE', '', 'Business', 'Constitutional Lawyer and former Education Minister was recipient of Lifetime Achievement Awards of the 16th ThisDay Awards in Lagos with Rabiu.'], ['Ola ORA', 'Cement Company of Northern Nigeria', 'Business', 'Project and Procurement Director of Cement Company of Northern Nigeria is Director of BUA Group.'], ['Trond WAERP', 'Cement Company of Northern Nigeria', 'Business', 'Finance Director of Cement Company of Northern Nigeria is Director of BUA Group.'], ['William Jefferson CLINTON Confirmed UHNW', '', 'Business', 'Former U.S. President presented the awards on the 16th ThisDay Awards in Lagos, of which Rabiu is a recipient.'], ['Confirmed UHNW', None, None, None], ['Uloma AIRHIENBUWA', 'BUA Group', 'Business', 'Strategy and Planning Manager of BUA Group.'], ['Israel DANAUTA', 'BUA Group', 'Business', 'Senior Legal Officer of BUA Group.'], ['Goddie ISIBOR', 'BUA Group', 'Business', 'Managing Director of BUA Sugar Refinery of BUA Group.'], ['Michael AONDOAKAA', '', 'Business', "Former Attorney General of the Federation and Minister of Justice of Nigeria reportedly took money from Rabiu to pave way for BUA Group's acquisition of Delta Steel."], ['David Alechenu Bonaventure MARK', 'Senate of Nigeria', 'Business', "President of the Senate of Nigeria attended Nigeria President Jonathan's Campaign Fund Raising Dinner in October, 2010 with Rabiu."], ['Anthonie van der BIJL', 'BUA Group', 'Business', 'General Manager of BUA Flour Mills of BUA Group.'], ['Goodluck Ebele JONATHAN', '', 'Business', 'Nigeria President held his Campaign Fund Raising Dinner in October, 2010, of which Rabiu was Chief Launcher.'], ['Mohammed Lawal MUKHTARI', 'BUA Group', 'Business', 'General Manager of Finance of BUA Sugar Refinery of BUA Group.'], ['Imran UR-RASHID', 'BUA Group', 'Business', 'Plant Manager of BUA Flour Mills of BUA Group.'], ['Ibrahim YARO', 'BUA Group', 'Business', 'General Manager of Marketing of BUA Sugar Refinery of BUA Group.'], ['David BARNETT', 'BUA Group', 'Business', 'Manager of London Office of BUA Group.'], ['Nasiru LADAN', 'BUA Group', 'Business', 'General Manager of BUA Cement of BUA Group.'], ['Alexander Uruemu IBRU Deceased', 'The Guardian', 'Business', "Publisher of the Guardian, Nigeria's leading newspaper was recipient of Lifetime Achievement Awards of the 16th ThisDay Awards in Lagos with Rabiu."], ['Olufemi OTEDOLA Confirmed UHNW', 'Forte Oil (African Petroleum)', 'Business', "Chairman of Forte Oil (African Petroleum) attended Nigeria President Jonathan's Campaign Fund Raising Dinner in October, 2010 with Rabiu."], ['Jimoh IBRAHIM Confirmed UHNW', 'Global Fleet Group', 'Business', "CEO of Global Fleet attended Nigeria President Jonathan's Campaign Fund Raising Dinner in October, 2010 with Rabiu."], ['Confirmed UHNW', None, None, None], ['Kelani ABIODUN', 'BUA Group', 'Business', 'Finance Manager of BUA Group.'], ['Mohammed Namadi SAMBO', '', 'Business', "Vice President of Nigeria attended Nigeria President Jonathan's Campaign Fund Raising Dinner in October, 2010 with Rabiu."], ['Finn ARNOLDSEN', 'Cement Company of Northern Nigeria', 'Business', 'Marketing Director of Cement Company of Northern Nigeria is Director of BUA Group.'], ['Siva Kumar ELLAPAN', 'BUA Group', 'Business', 'General Manager of BUA Sugar Refinery of BUA Group.']]
# [['Name', 'Company', 'Relationships', 'Remarks'], ['Cletus Madubugwu IBETO Confirmed UHNW', 'Ibeto Group', 'Business', ''], ['Confirmed UHNW', None, None, None], ['Kashim Bukar SHETTIMA Confirmed UHNW', 'Barbedos Group', 'Social', ''], ['Confirmed UHNW', None, None, None], ['Igho E. Charles SANOMI II Confirmed UHNW', 'Taleveras Group', 'Non-Profit/University Board', ''], ['Confirmed UHNW', None, None, None], ['Tope SHONUBI Confirmed UHNW', 'Sahara Group', 'Non-Profit/University Board', ''], ['Confirmed UHNW', None, None, None], ['Oluwagbemiga A. OYEBODE Confirmed UHNW', 'Aluko & Oyebode', 'Non-Profit/University Board', ''], ['Confirmed UHNW', None, None, None]]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[8], line 51
#      49 if result:
#      50     print(table_temp)
# ---> 51     out = correct_table_headers(table_temp)
#      53     # Add table count handling
#      54     table_counter[key] = table_counter.get(key, 0) + 1
#
# File ~/wealthnets/wealthnet_helpers.py:142, in correct_table_headers(table_temp)
#     139         table_temp2[0].insert(index, None)
#     141 # ensure we have the correct number of column names
# --> 142 assert len(table_temp2[0]) == len(df_temp.columns)
#     144 # assign the corrected headers to the dataframe
#     145 df_temp.columns = table_temp2[0]
#
# AssertionError:

# %%
# create a temporary dataframe without column headers
table_temp2 = copy.deepcopy(table_temp)
df_temp = pd.DataFrame(table_temp2[1:])

# identify indices of the extra columns
extra_columns_indices = [
    i for i, column in enumerate(df_temp.columns) 
    if df_temp.iloc[:, column].dropna().apply(
        lambda x: str(x).split()[-1] if ' ' in str(x) else str(x)
    ).isin({"UHNW", "VHNW", "Deceased", "None"}).all()
]

# insert 'None' into column names at the identified indices
for index in extra_columns_indices:
    if table_temp2[0][index] is not None:
        table_temp2[0].insert(index, None)

# ensure we have the correct number of column names
#assert len(table_temp2[0]) == len(df_temp.columns)

# %%
len(table_temp2[0])
#len(df_temp.columns)
# Out:
# 5

# %%
table_temp2
# Out:
# [[None, 'Name', 'Company', 'Relationships', 'Remarks'],
#  ['Cletus Madubugwu IBETO Confirmed UHNW', 'Ibeto Group', 'Business', ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Kashim Bukar SHETTIMA Confirmed UHNW', 'Barbedos Group', 'Social', ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Igho E. Charles SANOMI II Confirmed UHNW',
#   'Taleveras Group',
#   'Non-Profit/University Board',
#   ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Tope SHONUBI Confirmed UHNW',
#   'Sahara Group',
#   'Non-Profit/University Board',
#   ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Oluwagbemiga A. OYEBODE Confirmed UHNW',
#   'Aluko & Oyebode',
#   'Non-Profit/University Board',
#   ''],
#  ['Confirmed UHNW', None, None, None]]

# %%
table_temp
# Out:
# [['Name', 'Company', 'Relationships', 'Remarks'],
#  ['Cletus Madubugwu IBETO Confirmed UHNW', 'Ibeto Group', 'Business', ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Kashim Bukar SHETTIMA Confirmed UHNW', 'Barbedos Group', 'Social', ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Igho E. Charles SANOMI II Confirmed UHNW',
#   'Taleveras Group',
#   'Non-Profit/University Board',
#   ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Tope SHONUBI Confirmed UHNW',
#   'Sahara Group',
#   'Non-Profit/University Board',
#   ''],
#  ['Confirmed UHNW', None, None, None],
#  ['Oluwagbemiga A. OYEBODE Confirmed UHNW',
#   'Aluko & Oyebode',
#   'Non-Profit/University Board',
#   ''],
#  ['Confirmed UHNW', None, None, None]]
